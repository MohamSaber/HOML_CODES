# %%
import yfinance as yf
data = yf.download('AAPL', start='2020-01-01', end='2024-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.716080   72.776606   71.466820   71.721026  135480400
# 2020-01-03   72.009125   72.771752   71.783969   71.941336  146322800
# 2020-01-06   72.582893   72.621631   70.876060   71.127851  118387200
# 2020-01-07   72.241539   72.849216   72.021223   72.592586  108872000
# 2020-01-08   73.403641   73.706271   71.943751   71.943751  132079200
# ...                ...         ...         ...         ...        ...
# 2023-12-22  192.444580  194.243775  191.818335  194.015137   37122800
# 2023-12-26  191.897873  192.732856  191.679185  192.454528   28919300
# 2023-12-27  191.997253  192.345171  189.949550  191.341204   48087700
# 2023-12-28  192.424728  193.498285  192.017172  192.981384   34049900
# 2023-12-29  191.380966  193.239801  190.585738  192.742785   42628800
#
# [1006 rows x 5 columns]

# %%
# Install (if needed)

# Import
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt

# Set API Key
API_KEY = "X2TYIRRK0L6DD7CA"

# Fetch AAPL daily data
ts = TimeSeries(key=API_KEY, output_format='pandas')
data1, meta_data = ts.get_daily(symbol="AAPL", outputsize="compact")

# Plot closing price
data1['4. close'].plot(figsize=(10, 5), title="Apple (AAPL) Daily Closing Price")
plt.grid()
plt.show()

# %%
data1.head()
# Out:
#             1. open   2. high    3. low  4. close   5. volume
# date
# 2025-04-24  204.890  208.8299  202.9400    208.37  47310989.0
# 2025-04-23  206.000  208.0000  202.7990    204.60  52929165.0
# 2025-04-22  196.120  201.5900  195.9700    199.74  52976371.0
# 2025-04-21  193.265  193.8000  189.8112    193.16  46742537.0
# 2025-04-17  197.200  198.8335  194.4200    196.98  52164675.0
