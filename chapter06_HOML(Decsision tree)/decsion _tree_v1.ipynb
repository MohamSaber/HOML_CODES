# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
iris = load_iris(as_frame=True)
X_iris = iris.data[["petal length (cm)", "petal width (cm)"]].values
y_iris = iris.target

# %%
tree_clf = DecisionTreeClassifier(max_depth=2, random_state=42)
tree_clf.fit(X_iris, y_iris)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=42)

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plot_tree(tree_clf, feature_names=["petal length (cm)", "petal width (cm)"], class_names=tree_clf.classes_.astype(str), filled=True)
plt.show()

# %%
tree_clf.predict_proba([[5,1.5]])
# Out:
# array([[0.        , 0.90740741, 0.09259259]])

# %%
tree_clf.predict([[5,1.5]])
# Out:
# array([1])

# %% [markdown]
# ### we cann use the tree witout any conntrol or we can control hyperparameters to prevent overfitting

# %%
from sklearn.datasets import make_moons
x_moons,y_moons=make_moons(n_samples=150,noise=0.2,random_state=42)
import matplotlib.pyplot as plt
plt.scatter(x_moons[:, 0], x_moons[:, 1], c=y_moons, cmap='coolwarm', edgecolor='k', s=40)
plt.show()

# %%
tree_clf1=DecisionTreeClassifier(random_state=42) # without any specificastions
tree_clf2=DecisionTreeClassifier(min_samples_leaf=5,random_state=42)
tree_clf1.fit(x_moons,y_moons)
tree_clf2.fit(x_moons,y_moons)
# Out:
# DecisionTreeClassifier(min_samples_leaf=5, random_state=42)

# %%
X_moons_test, y_moons_test = make_moons(n_samples=1000, noise=0.2,random_state=43)
print(tree_clf1.score(X_moons_test, y_moons_test)*100)
print(tree_clf2.score(X_moons_test, y_moons_test)*100
)
# Out:
# 89.8
# 92.0

# %% [markdown]
# ## Regrssion

# %%
import numpy as np
from sklearn.tree import DecisionTreeRegressor
np.random.seed(42)
X_quad = np.random.rand(200, 1) - 0.5  # a single random input feature
y_quad = X_quad ** 2 + 0.025 * np.random.randn(200, 1)
tree_reg = DecisionTreeRegressor(max_depth=2)
tree_reg.fit(X_quad, y_quad)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
plt.figure(figsize=(12, 8))
plot_tree(tree_reg, 
          filled=True,  
          feature_names=["X"])
plt.title("Decision Tree Regressor (max_depth=2)")
plt.show()

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
pca_pipeline = make_pipeline(StandardScaler(), PCA())
X_iris_rotated = pca_pipeline.fit_transform(X_iris)
tree_clf_pca = DecisionTreeClassifier(max_depth=2, random_state=42)
tree_clf_pca.fit(X_iris_rotated, y_iris)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=42)
